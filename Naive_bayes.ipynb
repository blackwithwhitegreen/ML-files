# %% [markdown]
# <a href="https://colab.research.google.com/github/blackwithwhitegreen/ML-files/blob/main/Naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/play_tennis.csv')

# %%
df
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
df = df.drop('day',axis=1)

# %%
df
# Out:
#      outlook  temp humidity    wind play
# 0      Sunny   Hot     High    Weak   No
# 1      Sunny   Hot     High  Strong   No
# 2   Overcast   Hot     High    Weak  Yes
# 3       Rain  Mild     High    Weak  Yes
# 4       Rain  Cool   Normal    Weak  Yes
# 5       Rain  Cool   Normal  Strong   No
# 6   Overcast  Cool   Normal  Strong  Yes
# 7      Sunny  Mild     High    Weak   No
# 8      Sunny  Cool   Normal    Weak  Yes
# 9       Rain  Mild   Normal    Weak  Yes
# 10     Sunny  Mild   Normal  Strong  Yes
# 11  Overcast  Mild     High  Strong  Yes
# 12  Overcast   Hot   Normal    Weak  Yes
# 13      Rain  Mild     High  Strong   No

# %%
#Problem 1

#Outlook = Sunny, Temp = Hot,Humidity = High, Wind=Weak

#Play or No Play?

# %%
#Solution

# P(Yes,| Sunny,Hot,High,Weak)=P(Sunny | Yes) * P(Hot | Yes) * p(High | Yes) * P(Weak | Yes) * P(Yes)

# P(NO,| Sunny,Hot,High,Weak)=P(Sunny | NO) * P(Hot | NO) * p(High | NO) * P(Weak | NO) * P(NO)

#Play or NO Play?

# %%
#Solution

# P(Yes | Sunny,Hot,High,Weak) = P(Sunny|Yes) * p(Hot|Yes) * P(High | Yes) * P(Weak | Yes) * P(Yes)

# P(No | Sunny,Hot,High,Weak) = P(Sunny|NO) * p(Hot|NO) * P(High | NO) * P(Weak | NO) * P(NO)

# Compare and decide using the Maximun a posteriori rule.

# %%
# Problem 2

# Outlook = Overcast,Temp = Cold, Humidity = Low,Wind = weak
# Play or No Play?

# %%
# Solution

# P(Yes | Overcast,Cold,Low,Weak) = P(Overcast|Yes) * P(Cold | Yes) * P(Low | Yes) * P(Weak | Yes) * P(Yes)

# P(NO | Overcast,Cold,Low,Weak) = P(Overcast | No) * P(Cold | No) * P(Low | NO) * P(Weak | No) * P(NO)

# Compare and decide using the maximun a posteriori rule

# %%
# Training

# Creates a Lookup Table(Dictonary) and store in it.

# Testing

# %%
# P(Yes)
# P(NO)

# %%
# Lookup table is like set of probabilities.

# %%
df['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
py = 9/14
pn = 5/14

# %%
print(py)
print(pn)
# Out:
# 0.6428571428571429
# 0.35714285714285715

# %% [markdown]
# #Now finding the probablity for a columns, for both "Yes" and "NO".

# %% [markdown]
# #*Outlook*

# %%
pd.crosstab(df['outlook'],df['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
pon = 0 # For Overcast with NO
prn = 2/5 # For Rain with NO
psn = 3/5 # For Sunny with NO

poy = 4/9 # For Overcast with Yes.
pry = 3/9 # For Rain with Yes.
psy = 2/9 # For Sunny with Yes.

# %% [markdown]
# #*Temp*

# %%
pd.crosstab(df['temp'],df['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
PCoolNO = 1/5 # For Cool with No.
PHotNo = 2/5 # For Hot with NO.
PMildNO =2/5 # For Mild with NO.

PCoolYes = 3/9 # For Cool with Yes.
PHotYes = 2/9 # For Hot with Yes.
PMildYes = 4/9 # For Mild with Yes.

# %% [markdown]
# #*Humidity*

# %%
pd.crosstab(df['humidity'],df['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
PHighNo = 4/5 # For High with No.
PNormalNo= 1/5 # For Normal with NO.

PHighYes = 3/9 # For High with Yes.
PNormalYes = 6/9 # For Normal with Yes.

# %% [markdown]
# #*Wind*

# %%
pd.crosstab(df['wind'],df['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
PStrongNO = 3/5 # For Strong with NO.
PWeakNO = 2/5 # For Weak with NO.

PStrongYes = 3/9 # For Strong with Yes.
PWeakYes = 6/9 # For Weak with Yes.

# %% [markdown]
# #YES Probability

# %%
# Outlook = Sunny, Temp = Hot, Humidity = High, Wind = Weak

Pyes = py*psy*PHotYes*PHighYes*PWeakYes
print(Pyes)
# Out:
# 0.007054673721340388

# %% [markdown]
# #NO Probability

# %%
pno = pn*psn*PHotNo*PHighNo*PWeakNO
print(pno)
# Out:
# 0.02742857142857143

# %% [markdown]
# #Probability of No is greater the Yes, so the final answer is *NO PLAY*.
